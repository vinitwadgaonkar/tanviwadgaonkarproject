# %%
# Test 4: Simple plot
plt.figure(figsize=(8, 6))
plt.scatter(data['x'], data['y'], alpha=0.6)
plt.title('Jupyter is working! - Sample Plot')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.grid(True, alpha=0.3)
plt.show()
print("✓ Plotting works!")
